# %% [markdown]
# In this notebook, we will build an abstractive based text summarizer using deep learning from the scratch in python using keras

# %% [markdown]
# # <font color="red">Changes to Make</font>
# - Increase text-len from 30, out of the 100k samples taken, only 55% have a length > 30 tokens.

# %%
# verify gpu existence and tensorflow-recognition

# import TensorFlow
import tensorflow as tf

#Check the version of TensorFlow you are using
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.15.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install rouge

# %% [markdown]
# #Understanding the Problem Statement
#
# Customer reviews can often be long and descriptive. Analyzing these reviews manually, as you can imagine, is really time-consuming. This is where the brilliance of Natural Language Processing can be applied to generate a summary for long reviews.
#
# My objective here is to generate a summary for the Amazon Fine Food reviews using the abstraction-based approach we learned about above. The dataset can be downloaded from[ here ](https://www.kaggle.com/snap/amazon-fine-food-reviews)
#
# The dataset will be downloaded in a .zip file. Unzip the file-contents into the same directory where this notebook will be present.

# %% [markdown]
# #Custom Attention Layer
#
# Keras does not officially support attention layer. So, we could either implement my own attention layer or use a third-party implementation. I decided to go with the latter option.

# %%
import tensorflow as tf
import os

# the following imports have been changed w.r.t. original notebook
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Import the Libraries

# %%
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from tqdm.notebook import tqdm

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# #Read the dataset
#
# This dataset consists of reviews of fine foods from Amazon. The data spans a period of more than 10 years, including all ~500,000 reviews up to October 2012. These reviews include product and user information, ratings, plain text review, and summary. It also includes reviews from all other Amazon categories.
#
# We’ll take a sample of 100,000 reviews to reduce the training time of our model.

# %%
data=pd.read_csv("./drive/MyDrive/My Github Projects/Abstractive Summarizer/archive/Reviews.csv",nrows=100000)

# %%
data.head(3)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary  \
# 0  Good Quality Dog Food
# 1      Not as Advertised
# 2  "Delight" says it all
#
#                                                                                                                                                                                                       Text
# 0  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...

# %% [markdown]
# # Drop Duplicates and NA values

# %%
data.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
data.dropna(axis=0,inplace=True)#dropping na

# %% [markdown]
# # Information about dataset
#
# Let us look at datatypes and shape of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88419 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      88419 non-null  int64
#  1   ProductId               88419 non-null  object
#  2   UserId                  88419 non-null  object
#  3   ProfileName             88419 non-null  object
#  4   HelpfulnessNumerator    88419 non-null  int64
#  5   HelpfulnessDenominator  88419 non-null  int64
#  6   Score                   88419 non-null  int64
#  7   Time                    88419 non-null  int64
#  8   Summary                 88419 non-null  object
#  9   Text                    88419 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 7.4+ MB

# %% [markdown]
# #Preprocessing
#
# Performing basic preprocessing steps is very important before we get to the model building part. Using messy and uncleaned text data is a potentially disastrous move. So in this step, we will drop all the unwanted symbols, characters, etc. from the text that do not affect the objective of our problem.
#
# Here is the dictionary that I will use for expanding the contractions:

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %% [markdown]
# We will perform the below preprocessing tasks for our data:
#
# 1.Convert everything to lowercase
#
# 2.Remove HTML tags
#
# 3.Contraction mapping
#
# 4.Remove (‘s)
#
# 5.Remove any text inside the parenthesis ( )
#
# 6.Eliminate punctuations and special characters
#
# 7.Remove stopwords
#
# 8.Remove short words

# %%
stop_words = set(stopwords.words('english'))

def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)
    return (" ".join(long_words)).strip()

# %%
import time

#call the function
cleaned_text = []
st = time.time()
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))
print(f"Total time = {round(time.time() - st)}s")
# Out:
# Total time = 38s

# %%
# @title
import time

#call the function
cleaned_text = []
st = time.time()
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))
print(f"Total time = {round(time.time() - st)}s")
# Out:
# Total time = 24s

# %% [markdown]
# Let us look at the first five preprocessed reviews

# %%
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
#call the function
cleaned_summary = []
for t in tqdm(data['Summary'], "Processing summaries"):
    cleaned_summary.append(text_cleaner(t,1))
# Out:
# Processing summaries:   0%|          | 0/88419 [00:00<?, ?it/s]

# %% [markdown]
# Let us look at the first 10 preprocessed summaries

# %%
cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %% [markdown]
# #Drop empty rows

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %% [markdown]
# #Understanding the distribution of the sequences
#
# Here, I will analyze the length of the reviews and the summary to get an overall idea about the distribution of length of the text. This will help us fix the maximum length of the sequence:

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt30, cnt100, cnt60 = 0, 0, 0
for i in data['cleaned_text']:
    if(len(i.split())<=100):
      cnt100=cnt100+1
    if(len(i.split())<=60):
      cnt60=cnt60+1
    if(len(i.split())<=30):
      cnt30=cnt30+1
print(f"cutoff = 30 tokens: {round(100*cnt30/len(data['cleaned_text']), 2)}"
  f", cutoff = 60 tokens: {round(100*cnt60/len(data['cleaned_text']), 2)}"
  f", cutoff = 100 tokens: {round(100*cnt100/len(data['cleaned_text']), 2)}")
# Out:
# cutoff = 30 tokens: 54.97, cutoff = 60 tokens: 83.53, cutoff = 100 tokens: 94.49

# %% [markdown]
# Interesting. We can fix the maximum length of the summary to 8 since that seems to be the majority summary length.
#
# Let us understand the proportion of the length of summaries below 8

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9424894452681977

# %% [markdown]
# We observe that 94% of the summaries have length below 8. So, we can fix maximum length of summary to 8.
#
# Let us fix the maximum length of review to 30

# %%
# max_text_len=30
max_text_len = 60
# max_text_len = 100
max_summary_len=8

# %% [markdown]
# Let us select the reviews and summaries whose length falls below or equal to **max_text_len** and **max_summary_len**

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])

df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %% [markdown]
# Remember to add the **START** and **END** special tokens at the beginning and end of the summary. Here, I have chosen **sostok** and **eostok** as START and END tokens
#
# **Note:** Be sure that the chosen special tokens never appear in the summary

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %% [markdown]
# We are getting closer to the model building part. Before that, we need to split our dataset into a training and validation set. We’ll use 90% of the dataset as the training data and evaluate the performance on the remaining 10% (holdout set):

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.1,random_state=0,shuffle=True)

# %% [markdown]
# #Preparing the Tokenizer
#
# A tokenizer builds the vocabulary and converts a word sequence to an integer sequence.

# %% [markdown]
# ## Text Tokenizer

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

# %% [markdown]
# ### Rarewords and its Coverage
#
# Let us look at the proportion rare words and its total coverage in the entire text
#
# Here, I am defining the threshold to be 4 which means word whose count is below 4 is considered as a rare word

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value

print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 64.84018264840182
# Total Coverage of rare words: 1.9618736637233483

# %% [markdown]
# **Remember**:
#
#
# * **tot_cnt** gives the size of vocabulary (which means every unique words in the text)
#
# *   **cnt** gives me the no. of rare words whose count falls below threshold
#
# *  **tot_cnt - cnt** gives me the top most common words
#
# Let us define the tokenizer with top most common words for reviews.

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt)
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr)
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
x_voc
# Out:
# 12937

# %% [markdown]
# ## Summary Tokenizer

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

# %% [markdown]
# ### Rarewords and its Coverage
#
# Let us look at the proportion rare words and its total coverage in the entire summary
#
# Here, I am defining the threshold to be 6 which means word whose count is below 6 is considered as a rare word

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value

print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 76.79676753782668
# Total Coverage of rare words: 4.348151388185459

# %% [markdown]
# Let us define the tokenizer with top most common words for summary.

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt)
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr)
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val)

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %%
y_tr_seq[0]
# Out:
# [1, 378, 803, 276, 2044, 603, 2]

# %% [markdown]
# Let us check whether word count of start token is equal to length of the training data

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (63682, 63682)

# %% [markdown]
# Here, I am deleting the rows that contain only **START** and **END** tokens

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %% [markdown]
# # Model building
#
# We are finally at the model building part. But before we do that, we need to familiarize ourselves with a few terms which are required prior to building the model.
#
# **Return Sequences = True**: When the return sequences parameter is set to True, LSTM produces the hidden state and cell state for every timestep
#
# **Return State = True**: When return state = True, LSTM produces the hidden state and cell state of the last timestep only
#
# **Initial State**: This is used to initialize the internal states of the LSTM for the first timestep
#
# **Stacked LSTM**: Stacked LSTM has multiple layers of LSTM stacked on top of each other.
# This leads to a better representation of the sequence.
#
# Here, we are building a 3 stacked LSTM for the encoder:

# %%
from tensorflow.keras import backend as K
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60)]                 0         []
#
#  embedding (Embedding)       (None, 60, 100)              1293700   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 60, 300),            481200    ['embedding[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 60, 300),            721200    ['lstm[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  embedding_1 (Embedding)     (None, None, 100)            270000    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 60, 300),            721200    ['lstm_1[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  lstm_3 (LSTM)               [(None, None, 300),          481200    ['embedding_1[0][0]',
#                               (None, 300),                           'lstm_2[0][1]',
#                               (None, 300)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  ((None, None, 300),          180300    ['lstm_2[0][0]',
#  Layer)                       (None, None, 60))                      'lstm_3[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 600)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  time_distributed (TimeDist  (None, None, 2700)           1622700   ['concat_layer[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 5771500 (22.02 MB)
# Trainable params: 5771500 (22.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# I am using sparse categorical cross-entropy as the loss function since it converts the integer sequence to a one-hot vector on the fly. This overcomes any memory issues.

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %% [markdown]
# Remember the concept of early stopping? It is used to stop training the neural network at the right time by monitoring a user-specified metric. Here, I am monitoring the validation loss (val_loss). Our model will stop training once the validation loss increases:

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %% [markdown]
# We’ll train the model on a batch size of 128 and validate it on the holdout set (which is 10% of our dataset):

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=1,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 489/489 [==============================] - 273s 527ms/step - loss: 3.2033 - val_loss: 3.0108
# Epoch 2/50
# 489/489 [==============================] - 233s 477ms/step - loss: 2.8949 - val_loss: 2.8217
# Epoch 3/50
# 489/489 [==============================] - 232s 474ms/step - loss: 2.7667 - val_loss: 2.7220
# Epoch 4/50
# 489/489 [==============================] - 231s 473ms/step - loss: 2.6783 - val_loss: 2.6861
# Epoch 5/50
# 489/489 [==============================] - 230s 471ms/step - loss: 2.5956 - val_loss: 2.6038
# Epoch 6/50
# 489/489 [==============================] - 232s 474ms/step - loss: 2.5157 - val_loss: 2.5066
# Epoch 7/50
# 489/489 [==============================] - 229s 468ms/step - loss: 2.4529 - val_loss: 2.4820
# Epoch 8/50
# 489/489 [==============================] - 229s 468ms/step - loss: 2.4049 - val_loss: 2.4271
# Epoch 9/50
# 489/489 [==============================] - 228s 466ms/step - loss: 2.3640 - val_loss: 2.4049
# Epoch 10/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.3282 - val_loss: 2.3807
# Epoch 11/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.2902 - val_loss: 2.3575
# Epoch 12/50
# 489/489 [==============================] - 231s 472ms/step - loss: 2.2569 - val_loss: 2.3453
# Epoch 13/50
# 489/489 [==============================] - 229s 467ms/step - loss: 2.2271 - val_loss: 2.3345
# Epoch 14/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.1993 - val_loss: 2.3186
# Epoch 15/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.1746 - val_loss: 2.2990
# Epoch 16/50
# 489/489 [==============================] - 229s 469ms/step - loss: 2.1497 - val_loss: 2.2838
# Epoch 17/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.1258 - val_loss: 2.2829
# Epoch 18/50
# 489/489 [==============================] - 229s 467ms/step - loss: 2.1022 - val_loss: 2.2706
# Epoch 19/50
# 489/489 [==============================] - 228s 465ms/step - loss: 2.0785 - val_loss: 2.2545
# Epoch 20/50
# 489/489 [==============================] - 229s 467ms/step - loss: 2.0540 - val_loss: 2.2521
# Epoch 21/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.0303 - val_loss: 2.2504
# Epoch 22/50
# 489/489 [==============================] - 228s 467ms/step - loss: 2.0084 - val_loss: 2.2425
# Epoch 23/50
# 489/489 [==============================] - 229s 468ms/step - loss: 1.9853 - val_loss: 2.2369
# Epoch 24/50
# 489/489 [==============================] - 229s 469ms/step - loss: 1.9630 - val_loss: 2.2287
# Epoch 25/50
# 489/489 [==============================] - 228s 466ms/step - loss: 1.9427 - val_loss: 2.2273
# Epoch 26/50
# 489/489 [==============================] - 229s 468ms/step - loss: 1.9212 - val_loss: 2.2276
# Epoch 27/50
# 489/489 [==============================] - 228s 467ms/step - loss: 1.9014 - val_loss: 2.2290
# Epoch 27: early stopping

# %%
# take a look at the optimizer config
print(model.optimizer)
print(model.optimizer.learning_rate)
print(model.optimizer.momentum)
# Out:
# <keras.src.optimizers.rmsprop.RMSprop object at 0x7eca3110ae00>
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# 0.0

# %% [markdown]
# #Understanding the Diagnostic plot
#
# Now, we will plot a few diagnostic plots to understand the behavior of the model over time:

# %%
# @title
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# From the plot, we can infer that validation loss has increased after epoch 17 for 2 successive epochs. Hence, training is stopped at epoch 19.
#
# Next, let’s build the dictionary to convert the index to word for target and source vocabulary:

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %% [markdown]
# # Inference
#
# Set up the inference for the encoder and decoder:

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %% [markdown]
# We are defining a function below which is the implementation of the inference process :

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# The functions to convert an integer sequence to a word sequence for summary as well as the reviews:

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %% [markdown]
# ## Inference using 30 as max-source-sequence length
# Here are a few summaries generated by the model:

# %%
# @title
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: daughter used quaker instant oatmeal liked lot long time ago tried version like fact want finish sure maybe lots new ingredients artificial
# Original summary: not very good
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  good
#
#
# Review: liked coffee much subscribing dark rich smooth
# Original summary: makes great cup of java
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good coffee
#
#
# Review: like fool ordered box instead bag try disgusting smell like dead fish rinsed rinsed still smelled right light even look purple crack cannot believe stupid buy
# Original summary: gross
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not bad
#
#
# Review: flavorful packaged soup long time nice spicy taste good blend herbs cannot wait becomes available stores
# Original summary: delicious treat
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good stuff
#
#
# Review: taste like pop refreshing mouth liked healthier pop great taste refreshing
# Original summary: very good
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good flavor
#
#
# Review: really good snack pricey worth get em bulk start keep car great bike rides forget
# Original summary: kind bar
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great snack
#
#
# Review: way make pho need beef bones add soup base set even better restaurant
# Original summary: this is the only way make
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good
#
#
# Review: husband able tolerate taste felt decent amount energy could stomach taste felt energy
# Original summary: energy
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  good product
#
#
# Review: know wrong food cats could eat tried would start chewing would fall mouths tried hour avail know size food seem dislike taste could eat
# Original summary: cats could not eat it
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my cats love it
#
#
# Review: high quality right amount suger well done
# Original summary: high quality
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good
#
#
# Review: waste money disgusting product chocolate taste tastes like plastic lining paper carton using milk treated ultra high temperatures like fresh milk go get fresh milk hershey syrup want chocolate milk
# Original summary: please do not waste your money
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  it is ok
#
#
# Review: dogs love sweet potato chew agreed isnt chewy little nice two little shih tzu usually eat ish minutes dogs love taste love healthy
# Original summary: yummy healthy
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great for dogs
#
#
# Review: ordering herr paying shipping amazon amazon prime wide selection amazon herr okay heinz chips makes none better
# Original summary: off the
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: love larabars first discovered giving free event loved since good
# Original summary: yum
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  yummy
#
#
# Review: blend bitter wake mild end makes mornings calm delightful slow busy day harsh
# Original summary: great wake up taste
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good coffee
#
#
# Review: extract arrived days ordered great service tasted wonderful cookies made
# Original summary: great fast service and great product
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: cookies looked tasted either baked would also benefit touch stevia dry fruit
# Original summary: not baked
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  good
#
#
# Review: got routine eating oatmeal every morning breakfast four months ago great purchase given price home delivery subscribe save option amazing
# Original summary: love it
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: exercise regularly want aspartame whey protein decided add dry milk powder milk boost protein content wow taste great
# Original summary: great taste
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: best choice tried several options choice based taste smell hard resist stay away brew coffee morning recommend product
# Original summary: best choice so far
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  love this stuff
#
#
# Review: great taste package enough two cups water less depending concentrated want drink therefore enough powder cups think pretty good sweet bland distinct mango pineapple tropical taste
# Original summary: tastes great
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great taste
#
#
# Review: almost tastes like mini blueberry pie love one favorite thoroughly fallen love
# Original summary: excellent love the blueberry pecan
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great
#
#
# Review: price high product great possible touch price would make even better
# Original summary: in sea salt
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: delicious best snack bars happy made natural ingredients filler soy healthy snack lots fiber
# Original summary: delish
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  yummy
#
#
# Review: dog loves lickety stik bacon flavor since likes much plan getting flavors great liquid treat dog highly recommend lickety stik
# Original summary: great dog treat
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great for dog
#
#
# Review: took chance expecting oz least ox oz size description conveniently size label
# Original summary: in please
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not as pictured
#
#
# Review: order mom time tasted moist delicious coffee cake standard coffee cakes cannot say enough product sweet eater overly sweet wonderful
# Original summary: no the best
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great coffee
#
#
# Review: pricey essentially small bag hard crumbs maybe dog spoiled treats like third class treats definitely bottom doggie treat often simply walk away glad people like buying
# Original summary: waste of money
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  dog loves them
#
#
# Review: good healthy well priced buy bulk found prefer white cheddar version better though
# Original summary: pretty good
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good
#
#
# Review: like bold coffee bit disappointed bother stomach like like nice bold cup coffee cannot drink coffee bothers much pretty good substitute regular smooth little weak
# Original summary: weak but did not bother my stomach
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good coffee
#
#
# Review: since ordered trying first offering periodically never honestly blame pretty gross
# Original summary: the pack threw most of them out
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good product
#
#
# Review: cold find local stores one favorite snacks calories per pack excellent price
# Original summary: chex calorie snack
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great cereal
#
#
# Review: best flavor dr smoothie makes flavors good natural one best great taste pineapple hint coconut
# Original summary: best dr smoothie
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  best of the best
#
#
# Review: like strong coffee coffee rated found weak sickening taste
# Original summary: disapointed
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good coffee
#
#
# Review: saw peanut butter chocolate cereal knew try pleased eat chocolate breakfast feel guilty two kids love cereal well great eat alone favorite milk product yogurt mix homemade granola well
# Original summary: the yummy
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great for breakfast
#
#
# Review: fairly new haribo candy gummies fantastic twist gummi staple cola bottle crystallized lemony sugar outside sugar kind fine go every enough
# Original summary: these are soo good lemon lovers
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  best gummi bears
#
#
# Review: true also need decent scale tried caviar recipe everything worked perfectly first try fun easy make kit comes large enough samples looks like good uses
# Original summary: great to
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: enjoy sparkling ice talking rain discovered first time florida limited supply live many stores carry lemonade difficult find crisp refreshing love carbonation fruit balance
# Original summary: love lemonade sparkling ice
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  love this stuff
#
#
# Review: tulsi green tea great good iced tea well
# Original summary: green tea
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  tea
#
#
# Review: like tomatoes fresh flavorful also come carton welcome alternative metal cans impart flavor sometimes lined plastic containing
# Original summary: yummy tomatoes good packaging
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good
#
#
# Review: say agree first reviewer really good experience product buying friend came quickly product unique something everyone use customer service outstanding
# Original summary: fantastic
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good buy
#
#
# Review: searched google found cups price reasonable exceptionally fast delivery pleased order
# Original summary: green mountain cup breakfast blend
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great coffee
#
#
# Review: chips really good crisp delicious favorite flavor salt pepper second garlic parm good calories small bag bad say
# Original summary: amazing chips
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great chips
#
#
# Review: older shih tzu weight starting hip problems bought treats hide daily pills perfect soft around pills easily also easy chop smaller pieces use training treats
# Original summary: love these treats
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my puppy loves these
#
#
# Review: delicious added sugar perfect consistency eat plain add salads cottage cheese always without guilt easily best dried fruit ever
# Original summary: by far the best dried in
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  delicious
#
#
# Review: drink cups day verona italian french roast coffee wanted try lower acid version brand coffee smells tastes like vinegar totally unpalatable better drinking water acid coffee bothers
# Original summary: single worst coffee ever
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great coffee
#
#
# Review: changing review stars star product used creamy flavorful last two cases received gone drain coconut milk dull watery oily disgusting
# Original summary: by coconut
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  best coconut water ever
#
#
# Review: best pasta ever ate plus nutritional never go back worth increase price buying bulk makes affordable
# Original summary: pasta
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  best gluten free pasta
#
#
# Review: idea basically good one however large papillon could figure one matter hard tried food huge unless helped eventually would carry toy around give say tug jug trained
# Original summary: forever
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not bad
#
#
# Review: first time work fondant tryed one realy works need follow instructions
# Original summary: it works
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: glad gave try popped corn light fluffy dense chewy like brands great flavor air pop popcorn careful may find entire oz bowl stuff
# Original summary: terrific tasting movie theater popcorn
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good stuff
#
#
# Review: product good goes long way quite good one dd good product less
# Original summary: very good
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good
#
#
# Review: taste texture surprisingly close favorite brand super thin pretzel twists added benefit grams fat grams fiber grams protein wish came serving size packages instead though
# Original summary: super thin pretzel twist taste and texture
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  good but not too sweet
#
#
# Review: seems like deal saying yeah wont regret tastes like crap second pack
# Original summary: meh
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good product
#
#
# Review: love jack links beef steak top ordered box definately order highly recommend peppered beef steak perfect blend pepper spices smoked flavor make great anytime snack
# Original summary: of flavor
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good stuff
#
#
# Review: love medium full flavored roast smooth taste bitter acidic taste excellent coffee good value also try timothy kona good also
# Original summary: wonderful coffee
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great coffee
#
#
# Review: large hard great large dog little dogs eat break bit big size works well enjoy
# Original summary: my dogs love these
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: easy grow lush grass cat loves much better cat grass tried past
# Original summary: wonderful
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  cat loves it
#
#
# Review: taste good healthy rich delicious price show little bit expense compare website
# Original summary: good goat milk
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great
#
#
# Review: great product though jars little small original english version suspect changed suit american taste buds good highly recomend
# Original summary: mustard hot
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great
#
#
# Review: happy discover ramen variety product tastes great favorite flavor far chicken flavor beef teriyaki flavor little sweet still tastes good little sriracha
# Original summary: good for lunch on the go
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: tried six mcdougall soups think favorite find going back
# Original summary: favorite
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good
#
#
# Review: fine product great price seems city understand dents matter bring dents keep quality product inside
# Original summary: dents do not
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good product
#
#
# Review: tea works well unlike diet teas pain starts work cleans everything night love stuff
# Original summary: love this stuff
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great tea
#
#
# Review: love chips auto order every months taste great whole bag calories bag every day sure helped weight loss little bags eat huge amount
# Original summary: great purchase
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  pop chips
#
#
# Review: tried many different coffees never experienced tasting excellent coffee like weaver organic blend whole bean coffee full bodied sweet bitter taste highly recommend coffee anyone loves great cup coffee
# Original summary: exceptional coffee
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great coffee
#
#
# Review: expensive amazing treats dog goes crazy literally starts shaking gets whiff break apart easy smaller dog want make last longer
# Original summary: amazing treats
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great for training
#
#
# Review: loved brand best vanilla flavor others tried would buy better price
# Original summary: wolfgang puck coffee vanilla
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good
#
#
# Review: yummy eat right bag throw baked goods cereals etc mix kid pb sandwiches add even extra boost nutrition lunch found many hulls either order
# Original summary: love these
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  delicious
#
#
# Review: cats love weruva meow flavor sits bowl barely touch
# Original summary: they do not like this flavor
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  cat loves it
#
#
# Review: described good product needs added iced tea least oz water like strong tea taste good way get antioxidants daily
# Original summary: organic green tea extract
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  tea
#
#
# Review: way better hot sauce ordered past thank carrying product
# Original summary: texas hot sauce
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  best
#
#
# Review: buying regularly local market recently stopped carrying product family loves fast easy make perfect addition meal bought two boxes packets per unit came cheaper market sale great buy
# Original summary: tasty biscuits at great price
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: could find local stores anymore glad find amazon great tasting low fat snack
# Original summary: great snack
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great snack
#
#
# Review: nature path honey corn flakes really great tasting healthy gluten free highly recommend cereal
# Original summary: this cereal is really great
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great gluten free
#
#
# Review: three cats loved especially charlie morning stares refrigerator get milk tried brands turn noses
# Original summary: everyone loves it
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  cat loves it
#
#
# Review: person hard buy everything gift perfect like hot well burn butt lol enjoyed continue least weeks probably ask
# Original summary: great gift
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  delicious
#
#
# Review: recently found allergic wheat gluten milk love baking excited found pamela chocolate chip cookie mix friends even notice difference wonderful mix good easy highly recommend mix
# Original summary: this cookie mix is amazing
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  best gluten free pasta
#
#
# Review: caribou coffee definitely favorite coffee cup pack perfect probably order run even arrived day earlier anticipated arrival date
# Original summary: good coffee
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great coffee
#
#
# Review: delicious great price buying larger quantity makes apples affordable love organic looking crunchy dried apples perfect crunchy sweet without added oil sugar regret order
# Original summary: wonderful crunchy apple chips
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great snack
#
#
# Review: husband really enjoys baking mixed bisquick mayo together make biscuits kind traditional kind baking flour well leave aftertaste get cheaper flours impressed
# Original summary: best bread flour we have found
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  love this stuff
#
#
# Review: margarita mix excellent also cranberry martini mix pretty good really disappointing coconut taste aftertaste feels like something coating mouth drink bought bottle package toss
# Original summary: not very good
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not bad
#
#
# Review: close theater popcorn without go movies ingredients single packet makes pretty simple process
# Original summary: easy and good
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good popcorn
#
#
# Review: price pretty solid value noodles feeling taste like normal noodles carbs huge plus ordering
# Original summary: awesome for lo carb dieters
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good
#
#
# Review: older cats absolutely crazy treats take bag even different part house hear come running love giving treat enjoy much
# Original summary: my cats go for these treats
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great for cats
#
#
# Review: love great deal sold much supermarket bought ten bucks chewy spicy beware love cinnamon like mine expire
# Original summary: chewy and spicy
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good
#
#
# Review: much cheaper buy monthly ship save almost dollars jar local stores thing really long expiration date go month works okay
# Original summary: much cheaper here
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: convenient packaging babies love gobble right flavour best one happybaby line pouch foods worst would say amaranth chick chick nice subtle flavour nice texture highly recommend
# Original summary: love it and so do
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my baby loves it
#
#
# Review: great syrup pancakes oatmeal good consistency great flavor best price organic syrup seen anywhere definitely recommend
# Original summary: tasty good value it is organic
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: found spice blend dallas years back tell restaurant using grilled shrimp like cajun spice grilling fish recommend store dry place replace every year least lose flavor
# Original summary: good stuff
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good stuff
#
#
# Review: plain riceselect couscous delicious easy quick prepare great side item base main course far found bad product riceselect
# Original summary: yummy
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great snack
#
#
# Review: second order cans packaged damaged dented gather use bpa free cans guess sell cheaper amazon cases thailand excellent coconut milk
# Original summary: delicious
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  dented cans
#
#
# Review: really going purchase unless plastic bottle black walnut extract precious waste plastic container
# Original summary: photo is english walnut not black walnut
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  good product
#
#
# Review: bought several different brands favorite love smell eat spoon full even though pleasant slightly coconut flavor mess flavors cook found quit looking else satisfied using couple years
# Original summary: my favorite
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great taste
#
#
# Review: product light coconut fragrance taste makes much easier take supplement however alter taste food slightly keep mind cooking report later health benefits notice
# Original summary: smells and tastes good
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  good product
#
#
# Review: gevalia coffees little weak taste switched starbucks house blend africa
# Original summary: switched to starbucks
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  good coffee
#
#
# Review: buying least eight years must work well year dog teeth clean new puppy would recommend anyone
# Original summary: order
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great product
#
#
# Review: nice price glad see subscribe save option cups however undrinkable opinion seem watery like another reviewer said bad taste
# Original summary: good price bad taste
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  good product
#
#
# Review: crackers absolutely delicious snack ever addictive unfortunately come think order
# Original summary: the best
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  great taste
#
#
# Review: thought would love product found rather tasteless always use vanilla chai love use teabags get decent flavor caramel
# Original summary: disappointed
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  good stuff

# %% [markdown]
# ## Inference using 60 as max-source-sequence length

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: love order fresh always get individually wrapped sugary looks like someone grabbed threw bag shipped amount sent quality would buy mention half bag orange watermelon best manly lemons oranges flavors nobody want major disappointment
# Original summary: cheap bulk pack major disappointment
# 1/1 [==============================] - 1s 658ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not the same
#
#
# Review: good reviews led expect despite great color good viscosity syrup flavor lacked intensity continue quest elsewhere
# Original summary: once is enough
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not worth it
#
#
# Review: stuffer anyone needs small batches sausage quick easy use cleans rapidly think product use large amounts sausage stuffing pounds fo meat works well
# Original summary: good value
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: batch horrible since regular coffee stock tried one tastes smells awful buy flavor
# Original summary: awful smell and taste
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not worth the money
#
#
# Review: variety treats two favorite freeze dried nice big container always dogs running hear opening lid bought two
# Original summary: dogs favorite treat
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great treats
#
#
# Review: remind cheetos cheese great eat dairy love
# Original summary: yum
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  yummy
#
#
# Review: daughter food allergies hard find bar eat great tasting healthy know eat kind plus almond cashew whole family enjoys
# Original summary: my daughter loves these
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  yummy
#
#
# Review: love cincinnati chili quick easy way lots chili
# Original summary: it is the best
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  best chili chili
#
#
# Review: found shampoo nice nothing exceptional like clean smell rinse clean increase volume anything run home would buy fact rinse clean leave residue behind
# Original summary: nice
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: drinking pg tips tea almost years found consistently pleasurable tea others tried many teas chose grocery stores pg tips one find worth going extra effort obtain elsewhere recommend anyone try see
# Original summary: england favorite is mine too
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  excellent tea
#
#
# Review: talking neighbor getting keurig told get cocoa group beverages got ordered keurig think good rich creamy exactly want want cup cocoa would order
# Original summary: hot cocoa
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  hot cocoa
#
#
# Review: easy carry delicious honey around purse pocket
# Original summary: honey delicious
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: baby loves sweet potatoes essentially mix food sweet potatoes eat case could good bad thing depending wanted mix horribly runny like spooning formula mouth ick
# Original summary: too runny
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  yuck
#
#
# Review: bars great snack meal substitute need something quick good amount protein balanced made ingredients pronounce choose monthly shipment program cheap hard pressed find cheaper anywhere else
# Original summary: natural bars at an excellent price
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# Predicted summary:  great snack
#
#
# Review: tried beginning summer long bike ride refreshing amazing went limb bought hoping may good glad stuff amazing healthy delicious good skin alo packed vitamins natural minerals deliver best drink ever try buy local grocery store probably bought summer definitely worth try
# Original summary: best drink ever
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: bad starter puzzle especially price lab border collie totally figured within minutes super challenging issues cups located palm section paw hard get mouth almost impossible slide primary complaint toy yellow cups flimsy could easily cracked pieces minimal effort decent sized dog aggressive chewer definitely leave dog alone toy would recommend toy maybe think would ideal medium sized dogs smart good
# Original summary: affordable and not too
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  dog toy
#
#
# Review: bought amazon items purchased great product exception difficult seal close filled make one huge mess machine product ready prime time also cheap product filters leak sides understand cannot sealed better important important made china cannot sure free chemicals released brewing process products clearly state chemical free cannot remember bht take consideration buy something else please
# Original summary: do not even it
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not worth the money
#
#
# Review: drinking tea long time satisfied every cup flavor perfect weak strong also makes delicious iced tea usually drink caffeinated drinks like enjoy time day night worry caffeine keeping awake never problem grinds getting cup reviewers claim also never gotten cups bad seal would highly recommend product love great tasting cup tea ready instantly
# Original summary: perfect cup every time
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  excellent tea
#
#
# Review: like food every treacle pudding taste exactly personally like better number restaurants treacle pudding expect buying canned food stuff great
# Original summary: love it
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: love crystal light iced tea peach longer find grocery stores day ordered online maybe sent substitute sent iced peach mango wanted keep hate idea returning please send iced tea peach shown picture thanks
# Original summary: iced tea peach
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  love this tea
#
#
# Review: like taste drink nice fruity taste leave aftertaste probably order
# Original summary: better than expected
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great flavor
#
#
# Review: exactly might expect bought store pleased product made great party favors son rd birthday party
# Original summary: just what expected
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: favorite tea got natural sweetness beats sweet tea use make ice tea time great price amazon update understand pack boxes artificial ingredients listed pack natural ingredients
# Original summary: this tea
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  love this tea
#
#
# Review: coffee stale tasting gives good aroma thought would getting strong coffee name instead weak cannot return garbage go maybe sell next garage sale
# Original summary: not good coffee
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not bad
#
#
# Review: really expecting much cups give try considering price cups like use large cup setting keurig get coffee like coffee strong black always possible sf bay rainforest blend cups deliver great tasting strong cup coffee
# Original summary: great cup of coffee for less
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  good coffee
#
#
# Review: negative review certainly valid negative shopping experience chipotle ketchup delicious really ketchup quite barbecue tastes wonderful spicy swap either condiments heat nowhere near enough register chile heads quite noticeable prominent smoky chipotle flavor reason enough meat three meals day rarely use ketchup bbq anymore tempted use instead
# Original summary: my new
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not for me
#
#
# Review: smooth acid free coffee nice hearty taste easy stomach compared regular coffee yet still adds nice caffeine kick may seem hearty enough enjoy high test regular nice alternative love coffee cannot handle effects definitely alternative us tried decafe ease impact digestive system great black
# Original summary: smooth
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  love this coffee
#
#
# Review: love velveeta kinda knew would good plus im fan chicken vine program picked dinner kit love dinner kits make preparing meal sooooo much easier mean add chicken hard thing need water left overs mean dont picky eaters house kids dont usually finish plates ask till gone unless really like loved headed store pick highly recommended
# Original summary: wow this stuff is so good
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  like it
#
#
# Review: popcorn bad tasting live claim like theater popcorn think little pricey based quantity popped corn overall quality however convenient gone waste made full pack produces corn quantity half three quarter cup orville corn popped price reduced would give rating combination decent quality good price convenience
# Original summary: popcorn
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  popcorn
#
#
# Review: first one tea bag make one cup second price outrageous third taste mediocre fourth list ingredients list nutritional values ingredients list fifth list nutritional values entire box tea per bag expensive tea rip wise buy buy marketing hype
# Original summary: rip off
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  good tea
#
#
# Review: best price buying organic maple syrup years best price line master cleanse using syrup instead sugar outstanding deal
# Original summary: organic syrup healthy and delicious
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great syrup
#
#
# Review: sauce added great deal flavor dishes prepared thought discovered something brand new south jersey told friends one cooking gourmet said using rooster years found shop rite shocking happy found product cookbook better living
# Original summary: hot sauce amazon
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great stuff
#
#
# Review: great product excellent price tightly sealed fresh would recommend everyone
# Original summary: wonderful
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: best gummi bears ever delicious flavorful consistancy softer traditional gelatin based gummi bears flavor million times better little plastic bags come small want eat whole box time
# Original summary: so delicious
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  haribo gummy bears
#
#
# Review: internet trying find source produce used product able locate information production information regarding new york city base nothing regarding food grown packaged whether imported though certified organic discontinue use product
# Original summary: where is product made
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not bad
#
#
# Review: put peppercorns grinder use like black pepper peppercorns extremely flavorful product packaged plastic bag price could come reusable container
# Original summary: flavorful peppercorns
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great flavor
#
#
# Review: wife cereal almost every morning flavor overwhelmingly sweet cinnamon making lasting staple kitchen easy breakfast get old four pack lasts us month maybe little less would recommend trying like subscribe save kashi heart heart honey toasted oat cereal ounce boxes bad either want give try
# Original summary: great breakfast that does not
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great cereal
#
#
# Review: much less buck per package costs easily make tastier breading entire family gave star rating much flavor texture added pork chops certainly easy take much fix breading saving extra couple minutes worth lack flavor opinion unfortunately would recommend product likely stay away shake bake products
# Original summary: bland and not worth it
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not bad
#
#
# Review: best tasting applesauce get mess spoon resealable cannot say enough supposed daughters lunch box buy double everybody house loves
# Original summary: easy on the go
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great snack
#
#
# Review: wolfgang puck hawaiian hazelnut coffee keurig brewer good medium strength coffee hazelnut flavor full body enjoyable anytime day really like coffee
# Original summary: wolfgang puck hawaiian hazelnut cup coffee
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  love it
#
#
# Review: mom gave box years ago recently gotten around trying excellent bought another box second opened first packet could smell changed recipe checking back two boxes confirmed cinnamon taste drink although aftertaste hint clove pretty expensive something tastes mixed child
# Original summary: cinnamon water
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  not bad
#
#
# Review: bought big bag mind strong pepper taste mind bag implies potato chips absolutely potato taste left snack like eating extremely salty onion powder snack going bag expected real potatos little oil baking finally sprinkled salt pepper long list things like cane sugar rice flour maltodextrin list ingredients goes looking baked potato salt pepper chips bother vs
# Original summary: packaging is misleading
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  yum
#
#
# Review: although bag pretty average dog food definitely higher end dog food cut usual dry dog food fresh looking appearance taste well dogs seemed like noticed seem eat dry dog food hungry rather serve however ate served sure nibble would finish good product expensive typical dog food afford go waste
# Original summary: high end gourmet dog food
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not for my dog
#
#
# Review: love body wash smells nice works great feels great skin add fact subscribe save deal great value sold
# Original summary: great product and value
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: find stove top popped popcorn toothsome microwave love mixed color popcorn purpose unable find reliably place area delighted able get online
# Original summary: great popcorn cannot find elsewhere
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great popcorn
#
#
# Review: second illy coffee product guess like strong bitter tasting lover overly strong coffee flavors like mild however husband loved ever illy product given try coffee drinker likes anything coffee give rating would would split difference like convenient drinks would fit nicely husband lunchbox work
# Original summary: not for me but my loved it
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  love this coffee
#
#
# Review: great tasting quality product great consistency recipes used many times reorder list
# Original summary: great tasting tomato sauce
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great for cooking
#
#
# Review: love coffee bitter hint chocolate like mocha drink almost every day
# Original summary: best cup
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great coffee
#
#
# Review: dog owners little tricks train dogs go relieve get cookie get beggin strip bacon dogs years dog smart habit cookie beggin strips die
# Original summary: it is bacon
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  dog treats
#
#
# Review: made cake frosted combination pillsbury already mixed frosting frosting cake absolutely delicious could tell mix highly recommend particular cake
# Original summary: best cake mix
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: love snacks little bit sweet loads crunchy almonds looking forward trying varieties
# Original summary: sweet nutty
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: containing recommended daily intake fiber bars fairly tasty way obtaining however expect oatmeal raisin cookie type snack larabar type snack either dryer many snacks also baked come across raw product either taste pleasant bit complex especially cocoa powder many snacks finally addictive snack good tempted finish box three days health food candy
# Original summary: of your daily fiber in healthy snack
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious snack
#
#
# Review: year old son feels opposite way hansen less heavily cherry flavored bit carbonated like son
# Original summary: like this better than the blue
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  not bad
#
#
# Review: usually buy starbucks buying item sale making coffee home heavy coffee drinker sometimes study need quick pick love product sometimes add little cinnamon grade aa really gives boost would definitely buy product think good price saw lot store
# Original summary: my to
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great coffee
#
#
# Review: shake bake around forever mother grandmother used works great quick dinner healthier deep frying use chicken pork turn great
# Original summary: quick and tasty dinner
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great soup
#
#
# Review: like idea chemical free cleanser first day used got painful acne never painful acne since broke big time smelled like rotting pineapple gross please save money think twice product
# Original summary: stay away
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not as pictured
#
#
# Review: pasta salad kit described kit pasta stir fry needless say surprised happy use pasta something ordering product
# Original summary: wrong description on item
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great pasta
#
#
# Review: company gets star rapid fast shipping great customer service product gets star flavor get addicted brand new indian sweets like inside butterfinger candy bar love sweet yet delicately sweet complex flavors heaven sure ordering regularly
# Original summary: little bit of
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: doctors confirm ibs started looking natural products could help symptoms something take everyday would hurt product wonderful drink glass tea soon stomach starts getting painful within minutes completing cup tea feel better tried brands weaker work may little well worth money
# Original summary: best tea for
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great tea
#
#
# Review: cannot wait try eggs lunch cups powerful might exceptional meat loaf spicy bell peppers
# Original summary: very powerful taste not snack
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great flavor
#
#
# Review: maybe way many bars perhaps spoiled best super boring opinion flavor
# Original summary: these are meh
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  not bad
#
#
# Review: taking manuka honey year really good stuff acid reflux gone take day cracker works cuts boils many many uses must get
# Original summary: natural healthy no more acid
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: pro excellent positive reinforcement treat training allows break exact size amount cons tends make mess floors conclusion natural balance food roll healthiest training food found dog prevent spoilage cut log sections refrigerate need week freeze sections later date
# Original summary: natural balance roll
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my dogs love these
#
#
# Review: really like looked cute little sachet found wanting ever even tea house flavor good
# Original summary: bought this after friend recommended it
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: buying spearmint altoids years loved product got new tin new great taste horrible tasted like menthol drag see artificial ingredients hope company sees feedback back original recipe lose lot customers lost
# Original summary: why did they change good thing
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not bad
#
#
# Review: brown rice loaf staple home best toasted great sandwiches buying bread years
# Original summary: we love the brown rice from
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great bread
#
#
# Review: cacao powder really best deal find phenomenal taste still really good better tasting far quality goes im really sure nutrient antioxidant level others better like believe especially price good stuff nonetheless
# Original summary: sweet deal on cacao
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great flavor
#
#
# Review: puzzled tags reviews state product sugar free first ingredient list sugar total grams carbohydrate per serving actually fan brand horchata really tasty prepared splenda product listing bit misleading disclaimer well good perhaps sugar free tag ought removed
# Original summary: not sugar free
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  not bad
#
#
# Review: bought month old year old loves hard feed lately picky year old loves pouches guess new novelty ever takes
# Original summary: my daughters love it
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  my dog loves these
#
#
# Review: good good would hoped daughter liked quite bit even better regular cheez likes mild mozzarella flavor though may kellogg going felt milder flavor make breath stink much regular cheez like initial smell taste kind know sour sharp pungent ate taste mild like smelled like plus nice change find still like cheddar cheez best
# Original summary: it will not the cheddar cheez it
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  okay but not great
#
#
# Review: bought tea last year favorite available hugely disappointed find green tea grassy avoid costs
# Original summary: pass
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great tea
#
#
# Review: months baby girl allergy cow milk proteins guarantee food one brands contain potential allergens also contain higher nutritional value foods sold market baby prefers warm put minutes hot water amaranth chick chick favorites
# Original summary: excelent food for allergic baby
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  baby loves it
#
#
# Review: good tea fast delivery davidson tea bulk herb pure org hibiscus ounce bag
# Original summary: good tea
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great tea
#
#
# Review: rehydration period make tasty healthy probiotic rich drink family really tasty sliced fresh ginger sliced organic lemon added finished product flavor drink fresh fruit dried fruit even juice name buy grains long keep feed live
# Original summary: awesome product
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious
#
#
# Review: consider true ginger beer tastes like strong ginger ale bite sweetend refined sugar raw sugar doesnt strange taste
# Original summary: ginger beer from jamaica
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  ginger ginger
#
#
# Review: bought gift husband interested working bonsai time thrilled enjoying maintaining
# Original summary: happy
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  great product
#
#
# Review: love noodles buy bulk save save save nice taste texture came unbroken ready cook excuse enjoy wide wonderful like restaurant low carbers jealous ha ha
# Original summary: and wonderful
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  delicious
#
#
# Review: purchased several different herbs spices frontier dill weed mustard seed anise etc bulk sizes really like quality better get grocery stores including sam club prices reasonable lot available free shipping option also major consideration
# Original summary: very high quality
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: looking great tasting healthy chocolate mix sweetened naturally diabetic husband likes kids love definitely order thank chef
# Original summary: great for diabetics and children
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  yummy
#
#
# Review: using swheat scoop years absolutely love one cat control odors well clumps nicely scooping best parts get face full choking clay dust change litter second litter box cat clean upstairs box every days flush away see reviews bug issues years seen one bug kind also rewards program great buy bags get one free plus send coupons time
# Original summary: best litter ever
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  my cat loves this
#
#
# Review: definitely minority opinion vanilla flavor strong tasted artificial someone looking tea accented vanilla using vanilla tea bag green tea bag makes mellow brew buy spiced chai decaf much better
# Original summary: not bigelow best
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  excellent tea
#
#
# Review: newmans makes really good coffee seems bold smooth overpowering would recommend anyone least try seems like one coffees middle road
# Original summary: great coffee
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  love it
#
#
# Review: lovely little hot sauce gave stars vs expecting serious heat said flavor really nice low heat flavor ratio makes hot sauce used everything enjoy
# Original summary: just the right amount of heat
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great sauce
#
#
# Review: treats best break smaller pieces use training treats would recommend dogswell anyone dogs love chicken jerky love cause digestive issues
# Original summary: wonderful
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great for training
#
#
# Review: highland sugarworks organic grade dark amber maple syrup choice glad made among best maple syrups ever tried organic would recommend anyone
# Original summary: excellent organic syrup
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious
#
#
# Review: jelly beans great tasting give good energy expect run miles lift pounds give good enough quick burst good suck perform activities
# Original summary: great tasting and good energy
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great product
#
#
# Review: like tea bought replacement another brand peach sweet ginger tea came teabag form good price works better way
# Original summary: very nice tea and great price
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great tea
#
#
# Review: excellent tea normally black tea drinker exception superb cold tummy ache must hand tea
# Original summary: lemon ginger tea
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  love this tea
#
#
# Review: flight one favorite meals bring trips healthy flavorful easy prepare excellent stuff
# Original summary: great taste healthy excellent for traveling
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious
#
#
# Review: love foods first son devoured happily second son also loves fruit mix great variety sons love peach oatmeal banana best overall great product high quality ingredients taste half bad course try boys loved
# Original summary: great food
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great for the go
#
#
# Review: best flavored cup ever recommend everyone great flavor given friends get hooked
# Original summary: love it
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  love it
#
#
# Review: watching eat prove satisfying wonderful snack dark chocolate pomegranate anti oxidants help health love
# Original summary: covered in chocolate
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious
#
#
# Review: german shorthaired pointer puppy difficult walk treats helpful keep handful pocket give one every time sits stays like small easy carry plus loves also bought salmon cat treats hit cats
# Original summary: great for training my puppy
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  my dog loves these
#
#
# Review: hated cup could wait done box toxic best say variety tastes like bitter yet weak sock water reading many good reviews blend received apprehensive trust reviews cup varieties
# Original summary: yuk
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  not my favorite
#
#
# Review: found hard peel paper wrapper try eating think meant eaten good dissolves mouth product absolutely delicious
# Original summary: try this delicious healthy product
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  delicious
#
#
# Review: great go late afternoon snack also eliminates work melting marshmallows mixing cereal kids love
# Original summary: move over rice treats
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  my dogs love these
#
#
# Review: ordered product received cannot review product poor delivery
# Original summary: order never
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  not what expected
#
#
# Review: first bought rice husband enjoy much dress adding small amounts chicken summer sausage meat however enjoy plain also purchased four jar assortment gifts great product buy
# Original summary: we think they are wonderful
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  great product
#
#
# Review: taste tastes several state friends better peanuts found salted always try keep hand usually stocked near tha actual diner probably keep ordering via great quality better price
# Original summary: peanuts
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  great tasting snack
#
#
# Review: dog loves treats cannot think treats dog love treats hard takes pound lab seconds eat based reviews look treat containing product china product china never buy brand
# Original summary: my dog loves these treats
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  my dog loves these

# %% [markdown]
# ### ROUGE scores

# %%
from nltk.translate.bleu_score import SmoothingFunction
from rouge import Rouge
import math
from tqdm.notebook import tqdm

preds, refs = [], []
for i in tqdm(range(0,100), "Inference"):
    refs.append(seq2summary(y_tr[i]))
    preds.append(decode_sequence(x_tr[i].reshape(1,max_text_len)))

# Initialize ROUGE scorer
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(preds, refs, avg=True)

# Print ROUGE scores
print(f"ROUGE-1 F1 score: {scores['rouge-1']['f']:.4f}")
print(f"ROUGE-2 F1 score: {scores['rouge-2']['f']:.4f}")
print(f"ROUGE-L F1 score: {scores['rouge-l']['f']:.4f}")
# Out:
# Inference:   0%|          | 0/100 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# ROUGE-1 F1 score: 0.1416
# ROUGE-2 F1 score: 0.0442
# ROUGE-L F1 score: 0.1391

# %% [markdown]
# This is really cool stuff. Even though the actual summary and the summary generated by our model do not match in terms of words, both of them are conveying the same meaning. Our model is able to generate a legible summary based on the context present in the text.
#
# This is how we can perform text summarization using deep learning concepts in Python.
#
# #How can we Improve the Model’s Performance Even Further?
#
# By **increasing the training dataset** size and building the model. The generalization capability of a deep learning model enhances with an increase in the training dataset size.
